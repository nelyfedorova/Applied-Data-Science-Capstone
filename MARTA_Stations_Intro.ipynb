# %% [markdown]
# <h1 align=center><font size = 5>Segmenting and Clustering MARTA Rail Stations in Atlanta</font></h1>

# %% [markdown]
# ## Abstract
#
# In this report, we use the Foursquare API and Folium library to explore and visualize data for venues around MARTA rail stations in Atlanta. First, we get the most common venues near each station. Next, we explore venue categories for each station. Finally, we use this data to group the stations into clusters using *k*-means and  hierarchical clustering algorithms.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px" >
#
# <font size = 3>
#
# <b>[Introduction/Business Problem](#item000)</b>
# <p>
# <b>[1. Download and Explore MARTA Data](#item100)</b>
# <p>
#     [1.0 Wikipedia Data](#item101)
#
#     [1.1 Folium MARTA Map](#item110)
#
#     [1.2 Foursquare Data](#item120)
# <p>
# <b>[2. Methodology](#item200)</b>
# <p>
# <b>[Results](#item500)</b>
# <p>
# <b>[Discussion](#item600)</b>
# <p>
# <b>[Conclusion](#item700)</b>
# </font>
# </div>

# %% [markdown]
# ## Introduction/Business Problem  <a class="anchor" id="item000"></a>

# %% [markdown]
# It this report, we are going to explore venues associated with each of 38 MARTA rail stations in Atlanta, Georgia.
#
# This might help us answer the following questions.
#
# * Why do people use MARTA?
# * What attracts them to each MARTA station and makes them go there?
# * Where do they go before\after riding MARTA?
# * Where do they spend the most time (and money)?
# * Are MARTA stations similar or dissimilar in respect to the venues near them?
# * Can we label each MARTA station with venue categories that are specific for this station?
#
# In our analysis, we can use Foursquare API to get the most popular venues near each MARTA station, k-means and hierarchical clustering for grouping similar stations, and Folium library to visualize our results.
#
# MARTA station names and their coordinates can be extracted from Wikipedia https://en.wikipedia.org/wiki/MARTA_rail

# %% [markdown]
# ## 1. Download and Explore MARTA Data  <a class="anchor" id="item100"></a>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### 1.0 Wikipedia Data <a class="anchor" id="item101"></a>

# %% [markdown]
# Atlanta MARTA rail network has a total of 38 stations. In order to segement the stations and explore them, we will essentially need a dataset that contains the list of MARTA stations with the latitude and logitude coordinates of each station.
#
# Luckily, this data exists for free on Wikipedia: https://en.wikipedia.org/wiki/MARTA_rail
# It can be easily downloaded and converted to Excel file.

# %%
stations = pd.read_excel('MARTA_stations.xlsx')
print(stations.shape)
stations.head()
# Out:
# (38, 8)
#        Station Code  Jurisdiction     Opened  Station Entries/Day (2013)  \
# 0      Airport   S7  College Park 1988-06-18                        9173
# 1  Arts Center   N5       Atlanta 1982-12-18                        6605
# 2        Ashby   W3       Atlanta 1979-12-22                        1791
# 3     Avondale   E7       Decatur 1979-06-30                        4327
# 4     Bankhead   P4       Atlanta 1992-12-12                        1903
#
#                Coordinates   Latitude  Longitude
# 0  33.640758°N 84.446341°W  33.640758 -84.446341
# 1  33.789705°N 84.387789°W  33.789705 -84.387789
# 2  33.756346°N 84.417556°W  33.756346 -84.417556
# 3  33.775277°N 84.281903°W  33.775277 -84.281903
# 4    33.77189°N 84.42884°W  33.771890 -84.428840

# %% [markdown]
# ### 1.1 Folium map of Atlanta <a class="anchor" id="item110"></a>

# %% [markdown]
# Now we can create a map of Atlanta with MARTA stations superimposed on top.

# %% [markdown]
# We will use geopy library to get the latitude and longitude values of Downtown Atlanta. In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>atlanta_explorer</em>, as shown below.

# %%
address = 'Downtown Atlanta, GA'

geolocator = Nominatim(user_agent="atlanta_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Atlanta are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Atlanta are 33.7509748, -84.3930464.

# %% [markdown]
# Let's visualize MARTA stations setting marker radius proportional to "Station Entries/Day (2013)".

# %%
# create map of Downtown Toronto using latitude and longitude values
map_downtown = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label, num  in zip(stations['Latitude'], stations['Longitude'], stations['Station'], stations['Station Entries/Day (2013)']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=num / 1000,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_downtown)  
    
map_downtown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Folium** is a great visualization library. Feel free to zoom into the above map, and click on each circle mark to reveal the name of the station.

# %%
print(stations.shape[0])
stations.head()
# Out:
# 38
#        Station Code  Jurisdiction     Opened  Station Entries/Day (2013)  \
# 0      Airport   S7  College Park 1988-06-18                        9173
# 1  Arts Center   N5       Atlanta 1982-12-18                        6605
# 2        Ashby   W3       Atlanta 1979-12-22                        1791
# 3     Avondale   E7       Decatur 1979-06-30                        4327
# 4     Bankhead   P4       Atlanta 1992-12-12                        1903
#
#                Coordinates   Latitude  Longitude
# 0  33.640758°N 84.446341°W  33.640758 -84.446341
# 1  33.789705°N 84.387789°W  33.789705 -84.387789
# 2  33.756346°N 84.417556°W  33.756346 -84.417556
# 3  33.775277°N 84.281903°W  33.775277 -84.281903
# 4    33.77189°N 84.42884°W  33.771890 -84.428840

# %% [markdown]
# ### 1.2 Foursquare Data <a class="anchor" id="item120"></a>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the stations and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %% [markdown]
# CLIENT_ID = '???????????' # your Foursquare ID
# CLIENT_SECRET = '??????????????' # your Foursquare Secret
# VERSION = '20180605' # Foursquare API version

# %%
# @hidden_cell

# %% [markdown]
# #### Let's explore the first station in our dataframe

# %% [markdown]
# Get the neighborhood's name.

# %%
stations.loc[0, 'Station']
# Out:
# 'Airport'

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %%
station_latitude = stations.loc[0, 'Latitude'] # neighborhood latitude value
station_longitude = stations.loc[0, 'Longitude'] # neighborhood longitude value
station_name = stations.loc[0, 'Station'] # neighborhood name
print('Latitude and longitude values of {} are {}, {}.'.format(station_name, 
                                                               station_latitude, 
                                                               station_longitude))
# Out:
# Latitude and longitude values of Airport are 33.640758, -84.446341.

# %% [markdown]
# Now, let's get the top 100 venues within a radius of 500 meters from the Aiport Station

# %% [markdown]
# First, let's create the GET request URL. Name your URL **url**.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    station_latitude, 
    station_longitude, 
    radius, 
    LIMIT)

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d240b12f129b500253a9be1'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b5da9dff964a520ba6529e3-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b5da9dff964a520ba6529e3',
#        'location': {'address': 'Concourse C',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'at ATL Airport',
#         'distance': 146,
#         'formattedAddress': ['Concourse C (at ATL Airport)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640891019506924,
#           'lng': -84.44476896024125}],
#         'lat': 33.640891019506924,
#         'lng': -84.44476896024125,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f824d20e4b09a14788b96ee-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'id': '507c8c4091d498d9fc8c67a9',
#          'name': 'Public Art',
#          'pluralName': 'Public Art',
#          'primary': True,
#          'shortName': 'Public Art'}],
#        'id': '4f824d20e4b09a14788b96ee',
#        'location': {'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 185,
#         'formattedAddress': ['Atlanta, GA 30337', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.6400587434438,
#           'lng': -84.4445297253297}],
#         'lat': 33.6400587434438,
#         'lng': -84.4445297253297,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Metal Penguin',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f4d04d9e4b0ed3692e1d18d-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'primary': True,
#          'shortName': 'Art Gallery'}],
#        'id': '4f4d04d9e4b0ed3692e1d18d',
#        'location': {'address': 'Concourse T',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 352,
#         'formattedAddress': ['Concourse T (ATL Airport)',
#          'Atlanta, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64074521002435,
#           'lng': -84.4425388597648}],
#         'lat': 33.64074521002435,
#         'lng': -84.4425388597648,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Zimbabwe: A Tradition in Stone',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-570e549ecd10ab745f975199-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57352f',
#          'name': 'Airport Service',
#          'pluralName': 'Airport Services',
#          'primary': True,
#          'shortName': 'Airport Service'}],
#        'id': '570e549ecd10ab745f975199',
#        'location': {'address': 'North Terminal',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 221,
#         'formattedAddress': ['North Terminal (ATL Airport)',
#          'College Park, GA',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.641276492705096,
#           'lng': -84.44402933120728}],
#         'lat': 33.641276492705096,
#         'lng': -84.44402933120728,
#         'state': 'GA'},
#        'name': 'TSA PreCheck North',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-594debd22be42528bc4a0db8-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '594debd22be42528bc4a0db8',
#        'location': {'address': '6000 N Terminal Pkwy',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 105,
#         'formattedAddress': ['6000 N Terminal Pkwy',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.641678,
#           'lng': -84.44662}],
#         'lat': 33.641678,
#         'lng': -84.44662,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fa169a6121ddf131935fbaa-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4fa169a6121ddf131935fbaa',
#        'location': {'address': '6000 N Terminal Pkwy',
#         'cc': 'US',
#         'city': 'Atlanta Intl Airport',
#         'country': 'United States',
#         'distance': 222,
#         'formattedAddress': ['6000 N Terminal Pkwy',
#          'Atlanta Intl Airport, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640947,
#           'lng': -84.443954}],
#         'lat': 33.640947,
#         'lng': -84.443954,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b8f251e20dc6400254bcd13-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57350b',
#          'name': 'Food Stand',
#          'pluralName': 'Food Stands',
#          'primary': True,
#          'shortName': 'Food Stand'}],
#        'id': '5b8f251e20dc6400254bcd13',
#        'location': {'address': '6000 N. Terminal Way Atrium Location',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 146,
#         'formattedAddress': ['6000 N. Terminal Way Atrium Location',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640931,
#           'lng': -84.444774}],
#         'lat': 33.640931,
#         'lng': -84.444774,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': "Auntie Anne's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5643ce34498ea4f81db3a348-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'primary': True,
#          'shortName': 'Caribbean'}],
#        'id': '5643ce34498ea4f81db3a348',
#        'location': {'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'distance': 350,
#         'formattedAddress': ['College Park, GA', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64000911686688,
#           'lng': -84.44266448204162}],
#         'lat': 33.64000911686688,
#         'lng': -84.44266448204162,
#         'state': 'GA'},
#        'name': "Papi's Cuban and Caribbean Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fb02d60e4b08159087f8b33-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57352f',
#          'name': 'Airport Service',
#          'pluralName': 'Airport Services',
#          'primary': True,
#          'shortName': 'Airport Service'}],
#        'id': '4fb02d60e4b08159087f8b33',
#        'location': {'address': 'North Terminal',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 207,
#         'formattedAddress': ['North Terminal (ATL Airport)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64146898074518,
#           'lng': -84.44427317677822}],
#         'lat': 33.64146898074518,
#         'lng': -84.44427317677822,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'United Airlines Ticket Counter',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5893898e375c4a79fef9e255-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57352f',
#          'name': 'Airport Service',
#          'pluralName': 'Airport Services',
#          'primary': True,
#          'shortName': 'Airport Service'}],
#        'id': '5893898e375c4a79fef9e255',
#        'location': {'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'distance': 303,
#         'formattedAddress': ['College Park, GA', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64044974711368,
#           'lng': -84.44308393956577}],
#         'lat': 33.64044974711368,
#         'lng': -84.44308393956577,
#         'state': 'GA'},
#        'name': 'Clear Security Checkpoint',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ee68b390e011d524825c402-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4eb1bc533b7b2c5b1d4306cb',
#          'name': 'Airport Lounge',
#          'pluralName': 'Airport Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '4ee68b390e011d524825c402',
#        'location': {'address': 'Concourse T, Gate T6',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 361,
#         'formattedAddress': ['Concourse T, Gate T6 (ATL Airport)',
#          'Atlanta, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.63994822000257,
#           'lng': -84.4425592020606}],
#         'lat': 33.63994822000257,
#         'lng': -84.4425592020606,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Delta Sky Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4de0019dd4c040523e997f5d-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'primary': True,
#          'shortName': 'Apparel'}],
#        'id': '4de0019dd4c040523e997f5d',
#        'location': {'address': 'S Terminal Pkwy.',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'Atlanta Airport',
#         'distance': 159,
#         'formattedAddress': ['S Terminal Pkwy. (Atlanta Airport)',
#          'College Park, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64054120082708,
#           'lng': -84.44463738880019}],
#         'lat': 33.64054120082708,
#         'lng': -84.44463738880019,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Brooks Brothers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e3be2d7ae604542364f3811-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'id': '56aa371be4b08b9a8d57352f',
#          'name': 'Airport Service',
#          'pluralName': 'Airport Services',
#          'primary': True,
#          'shortName': 'Airport Service'}],
#        'id': '4e3be2d7ae604542364f3811',
#        'location': {'address': 'South Terminal',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 216,
#         'formattedAddress': ['South Terminal (ATL Airport)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64024033632484,
#           'lng': -84.44409394259542}],
#         'lat': 33.64024033632484,
#         'lng': -84.44409394259542,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Delta Air Lines Ticket Counter',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-544981d0498e6a33b8ab8779-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/airport_rentalcar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ef941735',
#          'name': 'Rental Car Location',
#          'pluralName': 'Rental Car Locations',
#          'primary': True,
#          'shortName': 'Rental Car'}],
#        'id': '544981d0498e6a33b8ab8779',
#        'location': {'address': '2200 Rental Car Cntr Pkwy 2210',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'distance': 37,
#         'formattedAddress': ['2200 Rental Car Cntr Pkwy 2210',
#          'College Park, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.6410935157711,
#           'lng': -84.44630358395996}],
#         'lat': 33.6410935157711,
#         'lng': -84.44630358395996,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Enterprise Rent-A-Car',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-519292db498ebf78397a1a03-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '519292db498ebf78397a1a03',
#        'location': {'address': 'Concourse T',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 372,
#         'formattedAddress': ['Concourse T (ATL Airport)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.639731,
#           'lng': -84.44251}],
#         'lat': 33.639731,
#         'lng': -84.44251,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': "Bojangles' Famous Chicken 'n Biscuits",
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '208220684'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c470557c047be9a22282f79-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'primary': True,
#          'shortName': 'Bus Station'}],
#        'id': '4c470557c047be9a22282f79',
#        'location': {'address': 'N Terminal Pkwy',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 27,
#         'formattedAddress': ['N Terminal Pkwy (ATL Airport)',
#          'College Park, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640890101491976,
#           'lng': -84.44658876491474}],
#         'lat': 33.640890101491976,
#         'lng': -84.44658876491474,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Atlanta Airport Ground Transportation',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51180fa3e4b05b41f709b6ad-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'primary': True,
#          'shortName': 'BBQ'}],
#        'id': '51180fa3e4b05b41f709b6ad',
#        'location': {'address': '6000 N Terminal Pkwy',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': '6000 S Terminal Pkwy',
#         'distance': 152,
#         'formattedAddress': ['6000 N Terminal Pkwy (6000 S Terminal Pkwy)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640421031105184,
#           'lng': -84.44474918795736}],
#         'lat': 33.640421031105184,
#         'lng': -84.44474918795736,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': "Shane's Rib Shack",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51242a50e4b068c30ac7c46b-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
#          'shortName': 'Juice Bar'}],
#        'id': '51242a50e4b068c30ac7c46b',
#        'location': {'address': 'Concourse T',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 445,
#         'formattedAddress': ['Concourse T (ATL Airport)',
#          'College Park, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.638389,
#           'lng': -84.442467}],
#         'lat': 33.638389,
#         'lng': -84.442467,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Jamba Juice',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ff226c4e4b099c410f27356-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b40',
#          'name': 'Betting Shop',
#          'pluralName': 'Betting Shops',
#          'primary': True,
#          'shortName': 'Betting Shop'}],
#        'id': '4ff226c4e4b099c410f27356',
#        'location': {'address': 'South Terminal Atlanta Jackson International Airport',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 154,
#         'formattedAddress': ['South Terminal Atlanta Jackson International Airport',
#          'Atlanta, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64024708036228,
#           'lng': -84.44479632022848}],
#         'lat': 33.64024708036228,
#         'lng': -84.44479632022848,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Georgia Lottery',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5c6b0ec36eda02002cdecf20-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '5c6b0ec36eda02002cdecf20',
#        'location': {'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'distance': 445,
#         'formattedAddress': ['College Park, GA 30320', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.643126,
#           'lng': -84.442463}],
#         'lat': 33.643126,
#         'lng': -84.442463,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Auntie Anne’s',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bfc087c588e36002ceab220-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '5bfc087c588e36002ceab220',
#        'location': {'address': 'Concourse T',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 387,
#         'formattedAddress': ['Concourse T (ATL Airport)',
#          'College Park, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.639613,
#           'lng': -84.442389}],
#         'lat': 33.639613,
#         'lng': -84.442389,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Subway',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be09d43652b0f47f9047311-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'primary': True,
#          'shortName': 'Electronics'}],
#        'id': '4be09d43652b0f47f9047311',
#        'location': {'address': 'Gate T4, Concourse T',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 360,
#         'formattedAddress': ['Gate T4, Concourse T (ATL Airport)',
#          'Atlanta, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.640316595459375,
#           'lng': -84.4424843788147}],
#         'lat': 33.640316595459375,
#         'lng': -84.4424843788147,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Brookstone',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56476a71498e0c99a3a7fcf6-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4eb1bc533b7b2c5b1d4306cb',
#          'name': 'Airport Lounge',
#          'pluralName': 'Airport Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '56476a71498e0c99a3a7fcf6',
#        'location': {'address': 'ATL Concourse T',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'crossStreet': 'ATL Airport',
#         'distance': 399,
#         'formattedAddress': ['ATL Concourse T (ATL Airport)',
#          'College Park, GA',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64145002192991,
#           'lng': -84.4421127932176}],
#         'lat': 33.64145002192991,
#         'lng': -84.4421127932176,
#         'state': 'GA'},
#        'name': 'United Club',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b7e5a32f709c100395136c4-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5b7e5a32f709c100395136c4',
#        'location': {'address': 'Concourse T, 6000 N. Terminal Parkway',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 370,
#         'formattedAddress': ['Concourse T, 6000 N. Terminal Parkway',
#          'Atlanta, GA 30337',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.64172135342479,
#           'lng': -84.44251302185842}],
#         'lat': 33.64172135342479,
#         'lng': -84.44251302185842,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': "Uncle Maddio's Pizza",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58ed8bcc15fb43399e275d5f-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/taxi_',
#           'suffix': '.png'},
#          'id': '53fca564498e1a175f32528b',
#          'name': 'Taxi Stand',
#          'pluralName': 'Taxi Stands',
#          'primary': True,
#          'shortName': 'Taxi Stand'}],
#        'id': '58ed8bcc15fb43399e275d5f',
#        'location': {'address': 'Lower Level, Door LS2',
#         'cc': 'US',
#         'city': 'College Park',
#         'country': 'United States',
#         'distance': 258,
#         'formattedAddress': ['Lower Level, Door LS2',
#          'College Park, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.63847023370738,
#           'lng': -84.44681781854628}],
#         'lat': 33.63847023370738,
#         'lng': -84.44681781854628,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': 'Rideshare Pickup Area (South Terminal)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c7f8a07dd27d0de0276c66-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '51c7f8a07dd27d0de0276c66',
#        'location': {'address': 'Hartsfield-Jackson Atlanta International Airport',
#         'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'crossStreet': '6000 North Terminal Parkway, Departures Level, 4th',
#         'distance': 269,
#         'formattedAddress': ['Hartsfield-Jackson Atlanta International Airport (6000 North Terminal Parkway, Departures Level, 4th)',
#          'Atlanta, GA 30320',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.63983842936167,
#           'lng': -84.44902896881102}],
#         'lat': 33.63983842936167,
#         'lng': -84.44902896881102,
#         'postalCode': '30320',
#         'state': 'GA'},
#        'name': "Maison Mathis 'Transit' - Atlanta International Airport",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50756313e4b03ae5c091b287-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_gate_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1eb931735',
#          'name': 'Airport Terminal',
#          'pluralName': 'Airport Terminals',
#          'primary': True,
#          'shortName': 'Terminal'}],
#        'id': '50756313e4b03ae5c091b287',
#        'location': {'cc': 'US',
#         'city': 'Atlanta',
#         'country': 'United States',
#         'distance': 316,
#         'formattedAddress': ['Atlanta, GA 30337', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.6406324858632,
#           'lng': -84.44975373899896}],
#         'lat': 33.6406324858632,
#         'lng': -84.44975373899896,
#         'postalCode': '30337',
#         'state': 'GA'},
#        'name': 'Hartsfield Jackson Economy Parking',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'College Park',
#   'headerLocation': 'College Park',
#   'headerLocationGranularity': 'city',
#   'suggestedBounds': {'ne': {'lat': 33.6452580045, 'lng': -84.44094585907645},
#    'sw': {'lat': 33.636257995499996, 'lng': -84.45173614092356}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'},
#     {'key': 'price', 'name': '$-$$$$'}],
#    'header': 'Tap to show:'},
#   'totalResults': 27}}

# %% [markdown]
# Now we will convert json data into a *pandas* dataframe. All the information is in the *items* key.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']

# flatten JSON
nearby_venues = json_normalize(venues) 

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                              name       categories        lat        lng
# 0                       Starbucks      Coffee Shop  33.640891 -84.444769
# 1                   Metal Penguin       Public Art  33.640059 -84.444530
# 2  Zimbabwe: A Tradition in Stone      Art Gallery  33.640745 -84.442539
# 3              TSA PreCheck North  Airport Service  33.641276 -84.444029
# 4                       Starbucks      Coffee Shop  33.641678 -84.446620

# %% [markdown]
# And how many venues were returned for the Airport Station by Foursquare?

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 27 venues were returned by Foursquare.

# %% [markdown]
# #### Let's create a function to repeat the same process to all MARTA stations

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Station', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Now we run the above function on each neighborhood and create a new dataframe called *atlanta_venues*.

# %%
atlanta_venues = getNearbyVenues(names=stations['Station'],
                                   latitudes=stations['Latitude'],
                                   longitudes=stations['Longitude']
                                  )
# Out:
# Airport
# Arts Center
# Ashby
# Avondale
# Bankhead
# Brookhaven/Oglethorpe
# Buckhead
# Chamblee
# Civic Center
# College Park
# Decatur
# Dome/GWCC/Philips Arena/CNN Center
# Doraville
# Dunwoody
# East Lake
# East Point
# Edgewood/Candler Park
# Five Points*
# Garnett
# Georgia State
# H. E. Holmes
# Indian Creek
# Inman Park/Reynoldstown
# Kensington
# King Memorial
# Lakewood/Fort McPherson
# Lenox
# Lindbergh Center
# Medical Center
# Midtown
# North Avenue
# North Springs
# Oakland City
# Peachtree Center
# Sandy Springs
# Vine City
# West End
# West Lake

# %% [markdown]
# Let's check the size of the resulting dataframe

# %%
print(atlanta_venues.shape)
atlanta_venues.head()
# Out:
# (1156, 7)
#    Station  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Airport              33.640758              -84.446341
# 1  Airport              33.640758              -84.446341
# 2  Airport              33.640758              -84.446341
# 3  Airport              33.640758              -84.446341
# 4  Airport              33.640758              -84.446341
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0                       Starbucks       33.640891       -84.444769
# 1                   Metal Penguin       33.640059       -84.444530
# 2  Zimbabwe: A Tradition in Stone       33.640745       -84.442539
# 3              TSA PreCheck North       33.641276       -84.444029
# 4                       Starbucks       33.641678       -84.446620
#
#     Venue Category
# 0      Coffee Shop
# 1       Public Art
# 2      Art Gallery
# 3  Airport Service
# 4      Coffee Shop

# %% [markdown]
# Let's check how many venues were returned for each neighborhood

# %%
atlanta_venues.groupby('Station').count()
# Out:
#                                     Neighborhood Latitude  \
# Station
# Airport                                                27
# Arts Center                                            48
# Ashby                                                  18
# Avondale                                               21
# Bankhead                                                3
# Brookhaven/Oglethorpe                                  19
# Buckhead                                              100
# Chamblee                                               17
# Civic Center                                           33
# College Park                                           12
# Decatur                                                61
# Dome/GWCC/Philips Arena/CNN Center                     58
# Doraville                                              15
# Dunwoody                                               61
# East Lake                                              16
# East Point                                             16
# Edgewood/Candler Park                                  10
# Five Points*                                           33
# Garnett                                                30
# Georgia State                                          33
# H. E. Holmes                                           15
# Indian Creek                                            3
# Inman Park/Reynoldstown                                40
# Kensington                                              4
# King Memorial                                          44
# Lakewood/Fort McPherson                                11
# Lenox                                                  25
# Lindbergh Center                                       46
# Medical Center                                          9
# Midtown                                               100
# North Avenue                                           42
# North Springs                                          11
# Oakland City                                           10
# Peachtree Center                                      100
# Sandy Springs                                          23
# Vine City                                              16
# West End                                               20
# West Lake                                               6
#
#                                     Neighborhood Longitude  Venue  \
# Station
# Airport                                                 27     27
# Arts Center                                             48     48
# Ashby                                                   18     18
# Avondale                                                21     21
# Bankhead                                                 3      3
# Brookhaven/Oglethorpe                                   19     19
# Buckhead                                               100    100
# Chamblee                                                17     17
# Civic Center                                            33     33
# College Park                                            12     12
# Decatur                                                 61     61
# Dome/GWCC/Philips Arena/CNN Center                      58     58
# Doraville                                               15     15
# Dunwoody                                                61     61
# East Lake                                               16     16
# East Point                                              16     16
# Edgewood/Candler Park                                   10     10
# Five Points*                                            33     33
# Garnett                                                 30     30
# Georgia State                                           33     33
# H. E. Holmes                                            15     15
# Indian Creek                                             3      3
# Inman Park/Reynoldstown                                 40     40
# Kensington                                               4      4
# King Memorial                                           44     44
# Lakewood/Fort McPherson                                 11     11
# Lenox                                                   25     25
# Lindbergh Center                                        46     46
# Medical Center                                           9      9
# Midtown                                                100    100
# North Avenue                                            42     42
# North Springs                                           11     11
# Oakland City                                            10     10
# Peachtree Center                                       100    100
# Sandy Springs                                           23     23
# Vine City                                               16     16
# West End                                                20     20
# West Lake                                                6      6
#
#                                     Venue Latitude  Venue Longitude  \
# Station
# Airport                                         27               27
# Arts Center                                     48               48
# Ashby                                           18               18
# Avondale                                        21               21
# Bankhead                                         3                3
# Brookhaven/Oglethorpe                           19               19
# Buckhead                                       100              100
# Chamblee                                        17               17
# Civic Center                                    33               33
# College Park                                    12               12
# Decatur                                         61               61
# Dome/GWCC/Philips Arena/CNN Center              58               58
# Doraville                                       15               15
# Dunwoody                                        61               61
# East Lake                                       16               16
# East Point                                      16               16
# Edgewood/Candler Park                           10               10
# Five Points*                                    33               33
# Garnett                                         30               30
# Georgia State                                   33               33
# H. E. Holmes                                    15               15
# Indian Creek                                     3                3
# Inman Park/Reynoldstown                         40               40
# Kensington                                       4                4
# King Memorial                                   44               44
# Lakewood/Fort McPherson                         11               11
# Lenox                                           25               25
# Lindbergh Center                                46               46
# Medical Center                                   9                9
# Midtown                                        100              100
# North Avenue                                    42               42
# North Springs                                   11               11
# Oakland City                                    10               10
# Peachtree Center                               100              100
# Sandy Springs                                   23               23
# Vine City                                       16               16
# West End                                        20               20
# West Lake                                        6                6
#
#                                     Venue Category
# Station
# Airport                                         27
# Arts Center                                     48
# Ashby                                           18
# Avondale                                        21
# Bankhead                                         3
# Brookhaven/Oglethorpe                           19
# Buckhead                                       100
# Chamblee                                        17
# Civic Center                                    33
# College Park                                    12
# Decatur                                         61
# Dome/GWCC/Philips Arena/CNN Center              58
# Doraville                                       15
# Dunwoody                                        61
# East Lake                                       16
# East Point                                      16
# Edgewood/Candler Park                           10
# Five Points*                                    33
# Garnett                                         30
# Georgia State                                   33
# H. E. Holmes                                    15
# Indian Creek                                     3
# Inman Park/Reynoldstown                         40
# Kensington                                       4
# King Memorial                                   44
# Lakewood/Fort McPherson                         11
# Lenox                                           25
# Lindbergh Center                                46
# Medical Center                                   9
# Midtown                                        100
# North Avenue                                    42
# North Springs                                   11
# Oakland City                                    10
# Peachtree Center                               100
# Sandy Springs                                   23
# Vine City                                       16
# West End                                        20
# West Lake                                        6

# %% [markdown]
# Let's save atlanta_venues to a backup csv file, just in case.

# %%
atlanta_venues.to_csv("MARTA_venues.csv",index=False) 
#atlanta_venues = pd.read_csv("MARTA_venues.csv")
atlanta_venues.head()
# Out:
#    Station  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Airport              33.640758              -84.446341
# 1  Airport              33.640758              -84.446341
# 2  Airport              33.640758              -84.446341
# 3  Airport              33.640758              -84.446341
# 4  Airport              33.640758              -84.446341
#
#                             Venue  Venue Latitude  Venue Longitude  \
# 0                       Starbucks       33.640891       -84.444769
# 1                   Metal Penguin       33.640059       -84.444530
# 2  Zimbabwe: A Tradition in Stone       33.640745       -84.442539
# 3              TSA PreCheck North       33.641276       -84.444029
# 4                       Starbucks       33.641678       -84.446620
#
#     Venue Category
# 0      Coffee Shop
# 1       Public Art
# 2      Art Gallery
# 3  Airport Service
# 4      Coffee Shop

# %% [markdown]
# Now we have all data ready for our analysis,

# %% [markdown]
# ### Thank you for reading!
#
# This notebook was created by Nelli Fedorova(https://www.linkedin.com/in/nelli-fedorova-7710b01a/). I hope you found this report interesting and educational.

# %% [markdown]
# This notebook is part of a course on **Coursera** called *Applied Data Science Capstone*. If you accessed this notebook outside the course, you can take this course online by clicking [here](http://cocl.us/DP0701EN_Coursera_Week3_LAB2).

# %% [markdown]
# <hr>
#
# Copyright &copy; 2018 [Cognitive Class](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
